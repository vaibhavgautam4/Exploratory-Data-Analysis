# %%
import numpy as np
import pandas as pd
import matplotlib as mp

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#         Locality            Place  Property Size (sq. meters)  \
# 0    South Delhi     Vasant Vihar                         200
# 1    North Delhi        Pitampura                         180
# 2     East Delhi      Mayur Vihar                         220
# 3     West Delhi   Rajouri Garden                         190
# 4  Central Delhi  Connaught Place                         210
#
#    Number of Floors Building Material  Total Material Cost (INR)  \
# 0                 2             Brick                    3800000
# 1                 1          Concrete                    2800000
# 2                 3              Wood                    4500000
# 3                 2             Brick                    3600000
# 4                 2          Concrete                    4000000
#
#    Total Labor Cost (INR)  Permit Cost (INR)  Utility Cost (INR)  Bedrooms  \
# 0                 1900000             160000              120000         4
# ...

# %% [markdown]
# clean data if not already clean

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#         Locality            Place  Property Size (sq. meters)  \
# 0    South Delhi     Vasant Vihar                         200
# 1    North Delhi        Pitampura                         180
# 2     East Delhi      Mayur Vihar                         220
# 3     West Delhi   Rajouri Garden                         190
# 4  Central Delhi  Connaught Place                         210
#
#    Number of Floors Building Material  Total Material Cost (INR)  \
# 0                 2             Brick                    3800000
# 1                 1          Concrete                    2800000
# 2                 3              Wood                    4500000
# 3                 2             Brick                    3600000
# 4                 2          Concrete                    4000000
#
#    Total Labor Cost (INR)  Permit Cost (INR)  Utility Cost (INR)  Bedrooms  \
# 0                 1900000             160000              120000         4
# ...

# %%
# data['Location (Delhi Locality)'].str.split(' - ')

# %%
# data['District'] = data['Location (Delhi Locality)'].str.split(' - ').str[0]
# data.head()

# data.insert(0, "Locality", True)

# %%
# data['Locality'] = data['Location (Delhi Locality)'].str.split(' - ').str[0]

# %%
# data.insert(1, "Place", True)

# %%
# data['Place'] = data['Location (Delhi Locality)'].str.split(' - ').str[1]
# data

# %%
# data = data.drop(['Location (Delhi Locality)','District'], axis=1)

# %%
data
# Out:
#                Locality                Place  Property Size (sq. meters)  \
# 0           South Delhi         Vasant Vihar                         200
# 1           North Delhi            Pitampura                         180
# 2            East Delhi          Mayur Vihar                         220
# 3            West Delhi       Rajouri Garden                         190
# 4         Central Delhi      Connaught Place                         210
# ..                  ...                  ...                         ...
# 136   West Delhi          Patel Nagar                                225
# 137   Central Delhi       Pragati Maidan                             210
# 138   South Delhi         Sarojini Nagar                             240
# 139   North Delhi         Model Town                                 215
# 140   East Delhi          Shakarpur                                  205
#
#      Number of Floors    Building Material  Total Material Cost (INR)  \
# ...

# %%
# data.to_csv('clean_house_data.csv')

# %%
categorical_features=[feature for feature in data.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['Locality', 'Place', 'Building Material', 'Supplier']

# %%
data[categorical_features].head()
# Out:
#         Locality            Place Building Material             Supplier
# 0    South Delhi     Vasant Vihar             Brick  ABC Building Supply
# 1    North Delhi        Pitampura          Concrete        XYZ Materials
# 2     East Delhi      Mayur Vihar              Wood        LMN Suppliers
# 3     West Delhi   Rajouri Garden             Brick     DEF Construction
# 4  Central Delhi  Connaught Place          Concrete         GHI Builders

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(data[feature].unique())))
# Out:
# The feature is Locality and number of categories are 15
# The feature is Place and number of categories are 95
# The feature is Building Material and number of categories are 6
# The feature is Supplier and number of categories are 91

# %%
from matplotlib import pyplot as plt

# %%
for feature in categorical_features:
    data=data.copy()
    data.groupby(feature)['Construction Cost (INR)'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Construction Cost (INR)')
    plt.title(feature)
    plt.show()

# %%
data1 = data[~data.duplicated()]

# %%
data1.to_csv('data.csv')

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Locality, Place, Property Size (sq. meters), Number of Floors, Building Material, Total Material Cost (INR), Total Labor Cost (INR), Permit Cost (INR), Utility Cost (INR), Bedrooms, Bathrooms, Supplier, Area of One Room (sq. meters), Cement Cost (INR per bag), Construction Cost (INR), Total Area of House (sq. meters), Number of Doors, Number of Windows, Number of Rooms, Total Cost (INR)]
# Index: []

# %%
data[data.duplicated(['Locality','Building Material','Place','Supplier'])]
# Out:
#                Locality                Place  Property Size (sq. meters)  \
# 80    South Delhi         Saket                                      180
# 102   East Delhi          Preet Vihar                                185
#
#      Number of Floors    Building Material  Total Material Cost (INR)  \
# 80                  3   Wood                                  4100000
# 102                 2   Brick                                 4000000
#
#      Total Labor Cost (INR)  Permit Cost (INR)  Utility Cost (INR)  Bedrooms  \
# 80                  1900000             160000              110000         4
# 102                 1700000             140000               95000         3
#
#      Bathrooms              Supplier  Area of One Room (sq. meters)  \
# 80           2   JKL Suppliers                                   18
# 102          2   PQR Suppliers                                   20
#
#      Cement Cost (INR per bag)  Construction Cost (INR)  \
# ...

# %%
# data[data['Place']=='Rajiv Chowk']
# Out:
#           Locality        Place  Property Size (sq. meters)  Number of Floors  \
# 19   Central Delhi  Rajiv Chowk                         210                 2
# 54   Central Delhi  Rajiv Chowk                         210                 2
# 89   Central Delhi  Rajiv Chowk                         210                 2
# 124  Central Delhi  Rajiv Chowk                         210                 2
# 159  Central Delhi  Rajiv Chowk                         210                 2
# 194  Central Delhi  Rajiv Chowk                         210                 2
#
#     Building Material  Total Material Cost (INR)  Total Labor Cost (INR)  \
# 19               Wood                    3800000                 1900000
# 54               Wood                    3800000                 1900000
# 89               Wood                    3800000                 1900000
# 124              Wood                    3800000                 1900000
# ...
